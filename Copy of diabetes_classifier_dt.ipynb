# %%
import os

# 🔐 ضع الـ token هنا
# ملاحظة: يجب أن يكون الـ token كاملاً وصحيحاً (بدءاً بـ ghp_...)
os.environ["GITHUB_TOKEN"] = "ghp_ABC123" # استبدل بـ PAT الخاص بك

USERNAME = "munera-alzamil" # حسابك
OWNER = "Rzan-AlSaadoun"   # صاحب المستودع الأصلي
REPO = "diabetes-classifier-dt"

# 1. عنوان URL لاستنساخ المستودع المنسوخ (الذي تملكه)
# ملاحظة: هذا يتطلب منك أن تكون قد قمت بالفعل بنسخ (Fork) مستودع Rzan-AlSaadoun إلى حسابك munera-alzamil
fork_url = f"https://{USERNAME}:{os.environ['GITHUB_TOKEN']}@github.com/{USERNAME}/{REPO}.git"
repo_dir = REPO

# 2. إعداد بياناتك (مهم للالتزامات)
# !git config --global user.email "your_email@example.com" # ضع بريدك الإلكتروني
# !git config --global user.name "{USERNAME}"

# 3. 🌀 استنساخ المستودع المنسوخ
print(f"Cloning {USERNAME}/{REPO}...")
# !git clone {fork_url}

# 4. 📂 الانتقال إلى المجلد
os.chdir(repo_dir)
print(f"Changed directory to {repo_dir}")

# 5. 🔗 إعداد المستودع الأصلي كـ "remote" (لإنشاء طلبات الدمج لاحقاً)
# !git remote add upstream https://github.com/{OWNER}/{REPO}.git
print("Upstream remote added for creating Pull Requests.")
# Out:
# Cloning munera-alzamil/diabetes-classifier-dt...
# Cloning into 'diabetes-classifier-dt'...
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/munera-alzamil/diabetes-classifier-dt.git/'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1653174605.py in <cell line: 0>()
#      23
#      24 # 4. 📂 الانتقال إلى المجلد
# ---> 25 os.chdir(repo_dir)
#      26 print(f"Changed directory to {repo_dir}")
#      27
#
# FileNotFoundError: [Errno 2] No such file or directory: 'diabetes-classifier-dt'
